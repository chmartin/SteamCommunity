# %% [markdown]
# # Study game per user information
#
# This notebook looks at the player game information on a game per user level.

# %%
import pandas as pd

# %%
df = pd.read_csv("player_game_info_100k.csv").drop("Unnamed: 0", axis='columns')

# %%
df.head()
# Out:
#    appid  playtime_2weeks  playtime_forever            steamid
# 0    240              NaN               307  76561198049785932
# 1   2600              NaN                65  76561198049785932
# 2   6910              NaN                 0  76561198049785932
# 3  15700              NaN                 0  76561198049785932
# 4    500              NaN                 1  76561198049785932

# %%
df.tail()
# Out:
#             appid  playtime_2weeks  playtime_forever            steamid
# 22547024   252130              NaN                 0  76561197993657300
# 22547025   282100              NaN                 0  76561197993657300
# 22547026   275390              NaN                 0  76561197993657300
# 22547027  1048540              NaN                 0  76561197993657300
# 22547028   684680              NaN                 0  76561197993657300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22547029 entries, 0 to 22547028
# Data columns (total 4 columns):
# appid               int64
# playtime_2weeks     float64
# playtime_forever    int64
# steamid             int64
# dtypes: float64(1), int64(3)
# memory usage: 688.1 MB

# %%
df['steamid'].nunique()
# Out:
# 27809

# %%
df_noZero = df[df['playtime_forever'] != 0]

# %%
df_noZero['steamid'].nunique()
# Out:
# 25093

# %%
df_noZero['appid'].nunique()
# Out:
# 27862

# %%
df['appid'].nunique()
# Out:
# 33492

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.groupby('steamid').sum()
# Out:
#                         appid  playtime_2weeks  playtime_forever
# steamid
# 76561197960265754   504029747              0.0              8044
# 76561197960265822    54209957              0.0                 0
# 76561197960265942   240805305            280.0            108097
# 76561197960266580    12015770              0.0             72162
# 76561197960267706   124962170            231.0             80884
# 76561197960268165    50663100           1149.0            379329
# 76561197960269245    67260677            227.0            262121
# 76561197960269551    50178250            651.0            195721
# 76561197960270280  2247356020              0.0                 0
# 76561197960270340   107102782          18341.0           1053421
# 76561197960270781   184814112            532.0            314365
# 76561197960270862   144202510           1386.0            343443
# 76561197960270975    65587460           1310.0            749789
# 76561197960271246    53039971              0.0            299126
# 76561197960272112  2495350791              0.0                 0
# 76561197960272121     6081690              0.0             54974
# 76561197960272218    45188102             84.0            181440
# 76561197960272940    91197551            273.0            135093
# 76561197960273222    28211410           2696.0            510257
# 76561197960274006    98088262           4311.0            163641
# 76561197960274467    18429970            904.0            331110
# 76561197960275251    42658980              0.0            197897
# 76561197960276598   116204440            114.0            279090
# 76561197960276662   423663534            278.0            157484
# 76561197960277083    84828030              0.0            223645
# 76561197960277275   150579022           2459.0            274368
# 76561197960279106    81474122             24.0            361511
# 76561197960280350   162707186              0.0                 0
# 76561197960281090   750435646              1.0            345392
# 76561197960281451   291407058              0.0             87959
# ...                       ...              ...               ...
# 76561198897173895     1265640            949.0             12423
# 76561198898028227     7767060           1950.0             18726
# 76561198901142820     1737480             87.0             13999
# 76561198907842586     5188670              4.0              1717
# 76561198909129862     7199730            200.0              2758
# 76561198926670941         730              0.0               477
# 76561198927476877      458060           2391.0             16939
# 76561198929181145    32989530              0.0              5285
# 76561198929813730         730              0.0               158
# 76561198929850390   185747470              0.0                 0
# 76561198930142451         730            160.0               160
# 76561198932101661     2402680            152.0              6311
# 76561198932831588         730            851.0             18618
# 76561198934290658    48449680           3627.0             19389
# 76561198937299483    14553550             92.0              4726
# 76561198939123189         730             22.0              5120
# 76561198947451605     7161260            335.0              6430
# 76561198949190505     5971800           1538.0             14527
# 76561198949330522      305660           3043.0              5018
# 76561198951032663    22753220           3759.0             18971
# 76561198952051765    21577770         141532.0            173851
# 76561198952065326     2077040           6330.0             24583
# 76561198953370889    10384630              0.0                 0
# 76561198953889212    32071810            503.0             10364
# 76561198956511884         730            458.0              7352
# 76561198959781335      886170              0.0                 0
# 76561198960349006    17164997           2087.0              7211
# 76561198963431665         730              0.0                 0
# 76561198966940097         730           2955.0              2955
# 76561198968591397    10385900          82548.0             82548
#
# [27809 rows x 3 columns]

# %%
df_noZero.groupby('steamid').sum()
# Out:
#                        appid  playtime_2weeks  playtime_forever
# steamid
# 76561197960265754   29500500              0.0              8044
# 76561197960265942   69175513            280.0            108097
# 76561197960266580    9369250              0.0             72162
# 76561197960267706   33110440            231.0             80884
# 76561197960268165   18171260           1149.0            379329
# 76561197960269245   37328430            227.0            262121
# 76561197960269551   34380310            651.0            195721
# 76561197960270340   36916071          18341.0           1053421
# 76561197960270781   98224480            532.0            314365
# 76561197960270862   72252540           1386.0            343443
# 76561197960270975   24337980           1310.0            749789
# 76561197960271246   39287160              0.0            299126
# 76561197960272121    2990830              0.0             54974
# 76561197960272218   35075700             84.0            181440
# 76561197960272940   64430761            273.0            135093
# 76561197960273222   18181780           2696.0            510257
# 76561197960274006   68267110           4311.0            163641
# 76561197960274467    9692730            904.0            331110
# 76561197960275251   18483560              0.0            197897
# 76561197960276598   54672840            114.0            279090
# 76561197960276662   44678563            278.0            157484
# 76561197960277083   49469820              0.0            223645
# 76561197960277275   79555402           2459.0            274368
# 76561197960279106   46548710             24.0            361511
# 76561197960281090  403463300              1.0            345392
# 76561197960281451   87979163              0.0             87959
# 76561197960282525   33079730              0.0            192946
# 76561197960282580    9415670           4840.0            133374
# 76561197960284265   78367870              7.0            386124
# 76561197960284353  418360821            327.0           1472000
# ...                      ...              ...               ...
# 76561198893341364    4010410              0.0              4391
# 76561198893898116    1473970           1135.0             22564
# 76561198894131268    4753963             45.0             16501
# 76561198894815278    1492170             76.0             11453
# 76561198897173895    1256990            949.0             12423
# 76561198898028227    4006790           1950.0             18726
# 76561198901142820     863930             87.0             13999
# 76561198907842586    3713560              4.0              1717
# 76561198909129862    4855970            200.0              2758
# 76561198926670941        730              0.0               477
# 76561198927476877     458060           2391.0             16939
# 76561198929181145    2345430              0.0              5285
# 76561198929813730        730              0.0               158
# 76561198930142451        730            160.0               160
# 76561198932101661     539540            152.0              6311
# 76561198932831588        730            851.0             18618
# 76561198934290658   26750350           3627.0             19389
# 76561198937299483    7809950             92.0              4726
# 76561198939123189        730             22.0              5120
# 76561198947451605    7161260            335.0              6430
# 76561198949190505    4936870           1538.0             14527
# 76561198949330522        730           3043.0              5018
# 76561198951032663    5305870           3759.0             18971
# 76561198952051765   20037080         141532.0            173851
# 76561198952065326     879840           6330.0             24583
# 76561198953889212        730            503.0             10364
# 76561198956511884        730            458.0              7352
# 76561198960349006    3141079           2087.0              7211
# 76561198966940097        730           2955.0              2955
# 76561198968591397    9894820          82548.0             82548
#
# [25093 rows x 3 columns]

# %%
top_1000_games = list(df_noZero.groupby('appid').sum()[['playtime_forever']].sort_values('playtime_forever',ascending=False)[:1000].index)

# %%
top_1000_users = list(df_noZero.groupby('steamid').sum()[['playtime_forever']].sort_values('playtime_forever',ascending=False)[:1000].index)

# %%
playtime_per_user = pd.DataFrame(df.groupby('steamid').sum()[['playtime_forever']])

# %%
count_per_user = df.groupby('steamid').count()

# %%
mean_per_user = df.groupby('steamid').mean()

# %%
std_per_user = df.groupby('steamid').std()

# %%
max_per_user = df.loc[df.groupby(["steamid"])["playtime_forever"].idxmax()]

# %%
playtime_per_user = playtime_per_user.reset_index()
count_per_user = count_per_user.reset_index()
mean_per_user = mean_per_user.reset_index()
std_per_user = std_per_user.reset_index()

# %%
print(playtime_per_user.info())
print(count_per_user.info())
print(mean_per_user.info())
print(std_per_user.info())
print(max_per_user.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27809 entries, 0 to 27808
# Data columns (total 2 columns):
# steamid             27809 non-null int64
# playtime_forever    27809 non-null int64
# dtypes: int64(2)
# memory usage: 434.6 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27809 entries, 0 to 27808
# Data columns (total 4 columns):
# steamid             27809 non-null int64
# appid               27809 non-null int64
# playtime_2weeks     27809 non-null int64
# playtime_forever    27809 non-null int64
# dtypes: int64(4)
# memory usage: 869.1 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27809 entries, 0 to 27808
# Data columns (total 4 columns):
# steamid             27809 non-null int64
# appid               27809 non-null float64
# playtime_2weeks     20420 non-null float64
# playtime_forever    27809 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 869.1 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27809 entries, 0 to 27808
# Data columns (total 4 columns):
# steamid             27809 non-null int64
# appid               27736 non-null float64
# playtime_2weeks     16382 non-null float64
# playtime_forever    27736 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 869.1 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27809 entries, 7739493 to 3038610
# Data columns (total 4 columns):
# appid               27809 non-null int64
# playtime_2weeks     10192 non-null float64
# playtime_forever    27809 non-null int64
# steamid             27809 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 1.1 MB
# None

# %%
total_per_user = playtime_per_user.merge(count_per_user,on='steamid',suffixes=('_sum', '_count'))

# %%
total_per_user = total_per_user.merge(mean_per_user,on='steamid',suffixes=('_count','_mean'))

# %%
total_per_user = total_per_user.merge(std_per_user,on='steamid',suffixes=('_mean','_std'))

# %%
total_per_user = total_per_user.merge(max_per_user,on='steamid',suffixes=('_std','_max'))

# %%
total_per_user.head()
# Out:
#              steamid  playtime_forever_sum  appid_count  \
# 0  76561197960265754                  8044         1599
# 1  76561197960265822                     0          341
# 2  76561197960265942                108097         1142
# 3  76561197960266580                 72162           50
# 4  76561197960267706                 80884          487
#
#    playtime_2weeks_count  playtime_forever_count     appid_mean  \
# 0                      0                    1599  315215.601626
# 1                      0                     341  158973.480938
# 2                      2                    1142  210862.788967
# 3                      0                      50  240315.400000
# 4                      1                     487  256595.831622
#
#    playtime_2weeks_mean  playtime_forever_mean      appid_std  \
# 0                   NaN               5.030644  183638.876234
# 1                   NaN               0.000000  182943.418608
# 2                 140.0              94.655867  176801.295365
# 3                   NaN            1443.240000  201783.828059
# 4                 231.0             166.086242  206081.055808
#
#    playtime_2weeks_std  playtime_forever_std  appid_max  playtime_2weeks_max  \
# 0                  NaN             51.720968     359320                  NaN
# 1                  NaN              0.000000         10                  NaN
# 2           164.048773            461.221806     346900                  NaN
# 3                  NaN           7626.036035        730                  NaN
# 4                  NaN           1238.967945        730                  NaN
#
#    playtime_forever
# 0              1130
# 1                 0
# 2              8799
# 3             53801
# 4             18306

# %%
total_per_user = total_per_user.drop(['playtime_2weeks_count','appid_mean','playtime_2weeks_mean','appid_std','playtime_2weeks_std','playtime_2weeks_max'],axis='columns')

# %%
total_per_user[total_per_user['playtime_forever_count'] != total_per_user['appid_count']]
# Out:
# Empty DataFrame
# Columns: [steamid, playtime_forever_sum, appid_count, playtime_forever_count, playtime_forever_mean, playtime_forever_std, appid_max, playtime_forever]
# Index: []

# %%
total_per_user = total_per_user.drop('playtime_forever_count',axis='columns')

# %%
total_per_user['playtime_forever_max'] = total_per_user['playtime_forever']

# %%
total_per_user = total_per_user.drop('playtime_forever',axis='columns')

# %%
total_per_user
# Out:
#                  steamid  playtime_forever_sum  appid_count  \
# 0      76561197960265754                  8044         1599
# 1      76561197960265822                     0          341
# 2      76561197960265942                108097         1142
# 3      76561197960266580                 72162           50
# 4      76561197960267706                 80884          487
# 5      76561197960268165                379329          305
# 6      76561197960269245                262121          242
# 7      76561197960269551                195721          249
# 8      76561197960270280                     0         6683
# 9      76561197960270340               1053421          464
# 10     76561197960270781                314365          991
# 11     76561197960270862                343443          512
# 12     76561197960270975                749789          268
# 13     76561197960271246                299126          272
# 14     76561197960272112                     0         6552
# 15     76561197960272121                 54974           67
# 16     76561197960272218                181440          270
# 17     76561197960272940                135093          285
# 18     76561197960273222                510257          171
# 19     76561197960274006                163641          458
# 20     76561197960274467                331110           72
# 21     76561197960275251                197897          424
# 22     76561197960276598                279090          584
# 23     76561197960276662                157484         1606
# 24     76561197960277083                223645          692
# 25     76561197960277275                274368          623
# 26     76561197960279106                361511          478
# 27     76561197960280350                     0          214
# 28     76561197960281090                345392         2881
# 29     76561197960281451                 87959         1568
# ...                  ...                   ...          ...
# 27779  76561198897173895                 12423            4
# 27780  76561198898028227                 18726           14
# 27781  76561198901142820                 13999            5
# 27782  76561198907842586                  1717           10
# 27783  76561198909129862                  2758           16
# 27784  76561198926670941                   477            1
# 27785  76561198927476877                 16939            2
# 27786  76561198929181145                  5285           89
# 27787  76561198929813730                   158            1
# 27788  76561198929850390                     0          418
# 27789  76561198930142451                   160            1
# 27790  76561198932101661                  6311           11
# 27791  76561198932831588                 18618            1
# 27792  76561198934290658                 19389          123
# 27793  76561198937299483                  4726           35
# 27794  76561198939123189                  5120            1
# 27795  76561198947451605                  6430           12
# 27796  76561198949190505                 14527           15
# 27797  76561198949330522                  5018            2
# 27798  76561198951032663                 18971           44
# 27799  76561198952051765                173851           47
# 27800  76561198952065326                 24583            7
# 27801  76561198953370889                     0           18
# 27802  76561198953889212                 10364           55
# 27803  76561198956511884                  7352            1
# 27804  76561198959781335                     0            3
# 27805  76561198960349006                  7211           35
# 27806  76561198963431665                     0            1
# 27807  76561198966940097                  2955            1
# 27808  76561198968591397                 82548           21
#
#        playtime_forever_mean  playtime_forever_std  appid_max  \
# 0                   5.030644             51.720968     359320
# 1                   0.000000              0.000000         10
# 2                  94.655867            461.221806     346900
# 3                1443.240000           7626.036035        730
# 4                 166.086242           1238.967945        730
# 5                1243.701639           9455.357241        730
# 6                1083.144628           9654.130786        730
# 7                 786.028112           6727.266964        730
# 8                   0.000000              0.000000         10
# 9                2270.303879          22905.044166     431960
# 10                317.219980           1463.113616     238960
# 11                670.787109           2851.344509     346110
# 12               2797.720149          12120.303924        730
# 13               1099.727941           5427.627351     238960
# 14                  0.000000              0.000000         10
# 15                820.507463           4295.811122      34220
# 16                672.000000           2496.443004     268850
# 17                474.010526           1890.341983     346900
# 18               2983.959064          14397.376630       4920
# 19                357.294760           1121.329226     834910
# 20               4598.750000          33338.234923        730
# 21                466.738208           2247.468795       4920
# 22                477.893836           3879.138636     627690
# 23                 98.059776           1290.810350      72850
# 24                323.186416           3017.226118        240
# 25                440.398074           2092.323333     252950
# 26                756.299163           2768.512011      49520
# 27                  0.000000              0.000000     230410
# 28                119.886151            344.356803      22380
# 29                 56.096301            253.091875     230410
# ...                      ...                   ...        ...
# 27779            3105.750000           6178.178770        730
# 27780            1337.571429           4759.333061        730
# 27781            2799.800000           5938.701727        730
# 27782             171.700000            235.929392     814380
# 27783             172.375000            360.312249        730
# 27784             477.000000                   NaN        730
# 27785            8469.500000          11963.539631        730
# 27786              59.382022            224.713277     360430
# 27787             158.000000                   NaN        730
# 27788               0.000000              0.000000        500
# 27789             160.000000                   NaN        730
# 27790             573.727273           1085.220447        550
# 27791           18618.000000                   NaN        730
# 27792             157.634146            487.001906     578310
# 27793             135.028571            397.876458        550
# 27794            5120.000000                   NaN        730
# 27795             535.833333            739.385105     413150
# 27796             968.466667           2957.822796        730
# 27797            2509.000000           3548.261828        730
# 27798             431.159091           1099.729141     335300
# 27799            3698.957447           3683.851003        730
# 27800            3511.857143           9282.241242        730
# 27801               0.000000              0.000000     252950
# 27802             188.436364           1397.481475        730
# 27803            7352.000000                   NaN        730
# 27804               0.000000              0.000000     351940
# 27805             206.028571           1151.284078        730
# 27806               0.000000                   NaN        730
# 27807            2955.000000                   NaN        730
# 27808            3930.857143           1330.528477        730
#
#        playtime_forever_max
# 0                      1130
# 1                         0
# 2                      8799
# 3                     53801
# 4                     18306
# 5                    118731
# 6                    149092
# 7                    102898
# 8                         0
# 9                    422632
# 10                    24168
# 11                    43339
# 12                   134297
# 13                    61419
# 14                        0
# 15                    31742
# 16                    28906
# 17                    25906
# 18                   151732
# 19                    19239
# 20                   283216
# 21                    32856
# 22                    89961
# 23                    44527
# 24                    63617
# 25                    37783
# 26                    39322
# 27                        0
# 28                     7038
# 29                     6359
# ...                     ...
# 27779                 12373
# 27780                 17869
# 27781                 13416
# 27782                   731
# 27783                  1355
# 27784                   477
# 27785                 16929
# 27786                  1466
# 27787                   158
# 27788                     0
# 27789                   160
# 27790                  3599
# 27791                 18618
# 27792                  3476
# 27793                  2073
# 27794                  5120
# 27795                  2781
# 27796                 11506
# 27797                  5018
# 27798                  4346
# 27799                 15154
# 27800                 24562
# 27801                     0
# 27802                 10364
# 27803                  7352
# 27804                     0
# 27805                  6817
# 27806                     0
# 27807                  2955
# 27808                  6025
#
# [27809 rows x 7 columns]

# %%
playtime_per_user_noZero = pd.DataFrame(df_noZero.groupby('steamid').sum()[['playtime_forever']])

# %%
count_per_user_noZero = df_noZero.groupby('steamid').count()

# %%
mean_per_user_noZero = df_noZero.groupby('steamid').mean()

# %%
std_per_user_noZero = df_noZero.groupby('steamid').std()

# %%
max_per_user_noZero = df_noZero.loc[df_noZero.groupby(["steamid"])["playtime_forever"].idxmax()]

# %%
playtime_per_user_noZero = playtime_per_user_noZero.reset_index()
count_per_user_noZero = count_per_user_noZero.reset_index()
mean_per_user_noZero = mean_per_user_noZero.reset_index()
std_per_user_noZero = std_per_user_noZero.reset_index()

# %%
print(playtime_per_user_noZero.info())
print(count_per_user_noZero.info())
print(mean_per_user_noZero.info())
print(std_per_user_noZero.info())
print(max_per_user_noZero.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25093 entries, 0 to 25092
# Data columns (total 2 columns):
# steamid             25093 non-null int64
# playtime_forever    25093 non-null int64
# dtypes: int64(2)
# memory usage: 392.2 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25093 entries, 0 to 25092
# Data columns (total 4 columns):
# steamid             25093 non-null int64
# appid               25093 non-null int64
# playtime_2weeks     25093 non-null int64
# playtime_forever    25093 non-null int64
# dtypes: int64(4)
# memory usage: 784.2 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25093 entries, 0 to 25092
# Data columns (total 4 columns):
# steamid             25093 non-null int64
# appid               25093 non-null float64
# playtime_2weeks     20420 non-null float64
# playtime_forever    25093 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 784.2 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25093 entries, 0 to 25092
# Data columns (total 4 columns):
# steamid             25093 non-null int64
# appid               24983 non-null float64
# playtime_2weeks     16381 non-null float64
# playtime_forever    24983 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 784.2 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25093 entries, 7739493 to 3038610
# Data columns (total 4 columns):
# appid               25093 non-null int64
# playtime_2weeks     10192 non-null float64
# playtime_forever    25093 non-null int64
# steamid             25093 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 980.2 KB
# None

# %%
total_per_user_noZero = playtime_per_user_noZero.merge(count_per_user_noZero,on='steamid',suffixes=('_sum', '_count'))

# %%
total_per_user_noZero = total_per_user_noZero.merge(mean_per_user_noZero,on='steamid',suffixes=('_count','_mean'))

# %%
total_per_user_noZero = total_per_user_noZero.merge(std_per_user_noZero,on='steamid',suffixes=('_mean','_std'))

# %%
total_per_user_noZero = total_per_user_noZero.merge(max_per_user_noZero,on='steamid',suffixes=('_std','_max'))

# %%
total_per_user_noZero.head()
# Out:
#              steamid  playtime_forever_sum  appid_count  \
# 0  76561197960265754                  8044          106
# 1  76561197960265942                108097          360
# 2  76561197960266580                 72162           30
# 3  76561197960267706                 80884          134
# 4  76561197960268165                379329           92
#
#    playtime_2weeks_count  playtime_forever_count     appid_mean  \
# 0                      0                     106  278306.603774
# 1                      2                     360  192154.202778
# 2                      0                      30  312308.333333
# 3                      1                     134  247092.835821
# 4                      1                      92  197513.695652
#
#    playtime_2weeks_mean  playtime_forever_mean      appid_std  \
# 0                   NaN              75.886792  164754.321264
# 1                 140.0             300.269444  180832.356140
# 2                   NaN            2405.400000  192706.741880
# 3                 231.0             603.611940  175639.237556
# 4                1149.0            4123.141304  206546.797623
#
#    playtime_2weeks_std  playtime_forever_std  appid_max  playtime_2weeks_max  \
# 0                  NaN            187.839259     359320                  NaN
# 1           164.048773            783.701749     346900                  NaN
# 2                  NaN           9791.328791        730                  NaN
# 3                  NaN           2311.529412        730                  NaN
# 4                  NaN          16931.177535        730               1149.0
#
#    playtime_forever
# 0              1130
# 1              8799
# 2             53801
# 3             18306
# 4            118731

# %%
total_per_user_noZero = total_per_user_noZero.drop(['playtime_2weeks_count','appid_mean','playtime_2weeks_mean','appid_std','playtime_2weeks_std','playtime_2weeks_max'],axis='columns')

# %%
total_per_user_noZero[total_per_user_noZero['playtime_forever_count'] != total_per_user_noZero['appid_count']]
# Out:
# Empty DataFrame
# Columns: [steamid, playtime_forever_sum, appid_count, playtime_forever_count, playtime_forever_mean, playtime_forever_std, appid_max, playtime_forever]
# Index: []

# %%
total_per_user_noZero = total_per_user_noZero.drop('playtime_forever_count',axis='columns')

# %%
total_per_user_noZero['playtime_forever_max'] = total_per_user_noZero['playtime_forever']

# %%
total_per_user_noZero = total_per_user_noZero.drop('playtime_forever',axis='columns')

# %%
total_per_user_noZero
# Out:
#                  steamid  playtime_forever_sum  appid_count  \
# 0      76561197960265754                  8044          106
# 1      76561197960265942                108097          360
# 2      76561197960266580                 72162           30
# 3      76561197960267706                 80884          134
# 4      76561197960268165                379329           92
# 5      76561197960269245                262121          138
# 6      76561197960269551                195721          157
# 7      76561197960270340               1053421          172
# 8      76561197960270781                314365          435
# 9      76561197960270862                343443          246
# 10     76561197960270975                749789          110
# 11     76561197960271246                299126          185
# 12     76561197960272121                 54974           26
# 13     76561197960272218                181440          158
# 14     76561197960272940                135093          196
# 15     76561197960273222                510257          113
# 16     76561197960274006                163641          287
# 17     76561197960274467                331110           44
# 18     76561197960275251                197897          186
# 19     76561197960276598                279090          240
# 20     76561197960276662                157484          197
# 21     76561197960277083                223645          274
# 22     76561197960277275                274368          287
# 23     76561197960279106                361511          265
# 24     76561197960281090                345392         1424
# 25     76561197960281451                 87959          572
# 26     76561197960282525                192946           89
# 27     76561197960282580                133374           36
# 28     76561197960284265                386124          306
# 29     76561197960284353               1472000         1140
# ...                  ...                   ...          ...
# 25063  76561198893341364                  4391           12
# 25064  76561198893898116                 22564            3
# 25065  76561198894131268                 16501           11
# 25066  76561198894815278                 11453            3
# 25067  76561198897173895                 12423            3
# 25068  76561198898028227                 18726            9
# 25069  76561198901142820                 13999            3
# 25070  76561198907842586                  1717            8
# 25071  76561198909129862                  2758           11
# 25072  76561198926670941                   477            1
# 25073  76561198927476877                 16939            2
# 25074  76561198929181145                  5285            9
# 25075  76561198929813730                   158            1
# 25076  76561198930142451                   160            1
# 25077  76561198932101661                  6311            7
# 25078  76561198932831588                 18618            1
# 25079  76561198934290658                 19389           70
# 25080  76561198937299483                  4726           20
# 25081  76561198939123189                  5120            1
# 25082  76561198947451605                  6430           12
# 25083  76561198949190505                 14527           11
# 25084  76561198949330522                  5018            1
# 25085  76561198951032663                 18971            8
# 25086  76561198952051765                173851           44
# 25087  76561198952065326                 24583            5
# 25088  76561198953889212                 10364            1
# 25089  76561198956511884                  7352            1
# 25090  76561198960349006                  7211            7
# 25091  76561198966940097                  2955            1
# 25092  76561198968591397                 82548           20
#
#        playtime_forever_mean  playtime_forever_std  appid_max  \
# 0                  75.886792            187.839259     359320
# 1                 300.269444            783.701749     346900
# 2                2405.400000           9791.328791        730
# 3                 603.611940           2311.529412        730
# 4                4123.141304          16931.177535        730
# 5                1899.427536          12743.332376        730
# 6                1246.630573           8447.943303        730
# 7                6124.540698          37373.464594     431960
# 8                 722.678161           2142.306230     238960
# 9                1396.109756           3992.547950     346110
# 10               6816.263636          18226.332432        730
# 11               1616.897297           6522.839379     238960
# 12               2114.384615           6772.987371      34220
# 13               1148.354430           3182.395340     268850
# 14                689.250000           2248.379716     346900
# 15               4515.548673          17539.967837       4920
# 16                570.177700           1373.813451     834910
# 17               7525.227273          42574.996910        730
# 18               1063.962366           3303.096985       4920
# 19               1162.875000           5992.201124     627690
# 20                799.411168           3616.702684      72850
# 21                816.222628           4758.012117        240
# 22                955.986063           3004.391473     252950
# 23               1364.192453           3607.799902      49520
# 24                242.550562            458.501121      22380
# 25                153.774476            400.925571     230410
# 26               2167.932584          11799.807792         10
# 27               3704.833333          14085.593768         10
# 28               1261.843137           6194.874383        730
# 29               1291.228070          19749.217656       4000
# ...                      ...                   ...        ...
# 25063             365.916667            360.307812     208140
# 25064            7521.333333          12996.157022        730
# 25065            1500.090909           3257.221867        730
# 25066            3817.666667           5990.195100        730
# 25067            4141.000000           7129.122246        730
# 25068            2080.666667           5921.898598        730
# 25069            4666.333333           7580.999692        730
# 25070             214.625000            247.057505     814380
# 25071             250.727273            416.086311        730
# 25072             477.000000                   NaN        730
# 25073            8469.500000          11963.539631        730
# 25074             587.222222            454.700115     360430
# 25075             158.000000                   NaN        730
# 25076             160.000000                   NaN        730
# 25077             901.571429           1272.006926        550
# 25078           18618.000000                   NaN        730
# 25079             276.985714            621.134271     578310
# 25080             236.300000            508.029433        550
# 25081            5120.000000                   NaN        730
# 25082             535.833333            739.385105     413150
# 25083            1320.636364           3425.872889        730
# 25084            5018.000000                   NaN        730
# 25085            2371.375000           1473.409257     335300
# 25086            3951.159091           3673.947784        730
# 25087            4916.600000          10982.112971        730
# 25088           10364.000000                   NaN        730
# 25089            7352.000000                   NaN        730
# 25090            1030.142857           2553.519886        730
# 25091            2955.000000                   NaN        730
# 25092            4127.400000           1004.775461        730
#
#        playtime_forever_max
# 0                      1130
# 1                      8799
# 2                     53801
# 3                     18306
# 4                    118731
# 5                    149092
# 6                    102898
# 7                    422632
# 8                     24168
# 9                     43339
# 10                   134297
# 11                    61419
# 12                    31742
# 13                    28906
# 14                    25906
# 15                   151732
# 16                    19239
# 17                   283216
# 18                    32856
# 19                    89961
# 20                    44527
# 21                    63617
# 22                    37783
# 23                    39322
# 24                     7038
# 25                     6359
# 26                   103041
# 27                    72818
# 28                    96507
# 29                   525703
# ...                     ...
# 25063                  1345
# 25064                 22528
# 25065                 10866
# 25066                 10723
# 25067                 12373
# 25068                 17869
# 25069                 13416
# 25070                   731
# 25071                  1355
# 25072                   477
# 25073                 16929
# 25074                  1466
# 25075                   158
# 25076                   160
# 25077                  3599
# 25078                 18618
# 25079                  3476
# 25080                  2073
# 25081                  5120
# 25082                  2781
# 25083                 11506
# 25084                  5018
# 25085                  4346
# 25086                 15154
# 25087                 24562
# 25088                 10364
# 25089                  7352
# 25090                  6817
# 25091                  2955
# 25092                  6025
#
# [25093 rows x 7 columns]

# %%
total_per_user
# Out:
#                  steamid  playtime_forever_sum  appid_count  \
# 0      76561197960265754                  8044         1599
# 1      76561197960265822                     0          341
# 2      76561197960265942                108097         1142
# 3      76561197960266580                 72162           50
# 4      76561197960267706                 80884          487
# 5      76561197960268165                379329          305
# 6      76561197960269245                262121          242
# 7      76561197960269551                195721          249
# 8      76561197960270280                     0         6683
# 9      76561197960270340               1053421          464
# 10     76561197960270781                314365          991
# 11     76561197960270862                343443          512
# 12     76561197960270975                749789          268
# 13     76561197960271246                299126          272
# 14     76561197960272112                     0         6552
# 15     76561197960272121                 54974           67
# 16     76561197960272218                181440          270
# 17     76561197960272940                135093          285
# 18     76561197960273222                510257          171
# 19     76561197960274006                163641          458
# 20     76561197960274467                331110           72
# 21     76561197960275251                197897          424
# 22     76561197960276598                279090          584
# 23     76561197960276662                157484         1606
# 24     76561197960277083                223645          692
# 25     76561197960277275                274368          623
# 26     76561197960279106                361511          478
# 27     76561197960280350                     0          214
# 28     76561197960281090                345392         2881
# 29     76561197960281451                 87959         1568
# ...                  ...                   ...          ...
# 27779  76561198897173895                 12423            4
# 27780  76561198898028227                 18726           14
# 27781  76561198901142820                 13999            5
# 27782  76561198907842586                  1717           10
# 27783  76561198909129862                  2758           16
# 27784  76561198926670941                   477            1
# 27785  76561198927476877                 16939            2
# 27786  76561198929181145                  5285           89
# 27787  76561198929813730                   158            1
# 27788  76561198929850390                     0          418
# 27789  76561198930142451                   160            1
# 27790  76561198932101661                  6311           11
# 27791  76561198932831588                 18618            1
# 27792  76561198934290658                 19389          123
# 27793  76561198937299483                  4726           35
# 27794  76561198939123189                  5120            1
# 27795  76561198947451605                  6430           12
# 27796  76561198949190505                 14527           15
# 27797  76561198949330522                  5018            2
# 27798  76561198951032663                 18971           44
# 27799  76561198952051765                173851           47
# 27800  76561198952065326                 24583            7
# 27801  76561198953370889                     0           18
# 27802  76561198953889212                 10364           55
# 27803  76561198956511884                  7352            1
# 27804  76561198959781335                     0            3
# 27805  76561198960349006                  7211           35
# 27806  76561198963431665                     0            1
# 27807  76561198966940097                  2955            1
# 27808  76561198968591397                 82548           21
#
#        playtime_forever_mean  playtime_forever_std  appid_max  \
# 0                   5.030644             51.720968     359320
# 1                   0.000000              0.000000         10
# 2                  94.655867            461.221806     346900
# 3                1443.240000           7626.036035        730
# 4                 166.086242           1238.967945        730
# 5                1243.701639           9455.357241        730
# 6                1083.144628           9654.130786        730
# 7                 786.028112           6727.266964        730
# 8                   0.000000              0.000000         10
# 9                2270.303879          22905.044166     431960
# 10                317.219980           1463.113616     238960
# 11                670.787109           2851.344509     346110
# 12               2797.720149          12120.303924        730
# 13               1099.727941           5427.627351     238960
# 14                  0.000000              0.000000         10
# 15                820.507463           4295.811122      34220
# 16                672.000000           2496.443004     268850
# 17                474.010526           1890.341983     346900
# 18               2983.959064          14397.376630       4920
# 19                357.294760           1121.329226     834910
# 20               4598.750000          33338.234923        730
# 21                466.738208           2247.468795       4920
# 22                477.893836           3879.138636     627690
# 23                 98.059776           1290.810350      72850
# 24                323.186416           3017.226118        240
# 25                440.398074           2092.323333     252950
# 26                756.299163           2768.512011      49520
# 27                  0.000000              0.000000     230410
# 28                119.886151            344.356803      22380
# 29                 56.096301            253.091875     230410
# ...                      ...                   ...        ...
# 27779            3105.750000           6178.178770        730
# 27780            1337.571429           4759.333061        730
# 27781            2799.800000           5938.701727        730
# 27782             171.700000            235.929392     814380
# 27783             172.375000            360.312249        730
# 27784             477.000000                   NaN        730
# 27785            8469.500000          11963.539631        730
# 27786              59.382022            224.713277     360430
# 27787             158.000000                   NaN        730
# 27788               0.000000              0.000000        500
# 27789             160.000000                   NaN        730
# 27790             573.727273           1085.220447        550
# 27791           18618.000000                   NaN        730
# 27792             157.634146            487.001906     578310
# 27793             135.028571            397.876458        550
# 27794            5120.000000                   NaN        730
# 27795             535.833333            739.385105     413150
# 27796             968.466667           2957.822796        730
# 27797            2509.000000           3548.261828        730
# 27798             431.159091           1099.729141     335300
# 27799            3698.957447           3683.851003        730
# 27800            3511.857143           9282.241242        730
# 27801               0.000000              0.000000     252950
# 27802             188.436364           1397.481475        730
# 27803            7352.000000                   NaN        730
# 27804               0.000000              0.000000     351940
# 27805             206.028571           1151.284078        730
# 27806               0.000000                   NaN        730
# 27807            2955.000000                   NaN        730
# 27808            3930.857143           1330.528477        730
#
#        playtime_forever_max
# 0                      1130
# 1                         0
# 2                      8799
# 3                     53801
# 4                     18306
# 5                    118731
# 6                    149092
# 7                    102898
# 8                         0
# 9                    422632
# 10                    24168
# 11                    43339
# 12                   134297
# 13                    61419
# 14                        0
# 15                    31742
# 16                    28906
# 17                    25906
# 18                   151732
# 19                    19239
# 20                   283216
# 21                    32856
# 22                    89961
# 23                    44527
# 24                    63617
# 25                    37783
# 26                    39322
# 27                        0
# 28                     7038
# 29                     6359
# ...                     ...
# 27779                 12373
# 27780                 17869
# 27781                 13416
# 27782                   731
# 27783                  1355
# 27784                   477
# 27785                 16929
# 27786                  1466
# 27787                   158
# 27788                     0
# 27789                   160
# 27790                  3599
# 27791                 18618
# 27792                  3476
# 27793                  2073
# 27794                  5120
# 27795                  2781
# 27796                 11506
# 27797                  5018
# 27798                  4346
# 27799                 15154
# 27800                 24562
# 27801                     0
# 27802                 10364
# 27803                  7352
# 27804                     0
# 27805                  6817
# 27806                     0
# 27807                  2955
# 27808                  6025
#
# [27809 rows x 7 columns]

# %%
total_per_user.head()
# Out:
#              steamid  playtime_forever_sum  appid_count  \
# 0  76561197960265754                  8044         1599
# 1  76561197960265822                     0          341
# 2  76561197960265942                108097         1142
# 3  76561197960266580                 72162           50
# 4  76561197960267706                 80884          487
#
#    playtime_forever_mean  playtime_forever_std  appid_max  \
# 0               5.030644             51.720968     359320
# 1               0.000000              0.000000         10
# 2              94.655867            461.221806     346900
# 3            1443.240000           7626.036035        730
# 4             166.086242           1238.967945        730
#
#    playtime_forever_max
# 0                  1130
# 1                     0
# 2                  8799
# 3                 53801
# 4                 18306

# %%
total_per_user_noZero.head()
# Out:
#              steamid  playtime_forever_sum  appid_count  \
# 0  76561197960265754                  8044          106
# 1  76561197960265942                108097          360
# 2  76561197960266580                 72162           30
# 3  76561197960267706                 80884          134
# 4  76561197960268165                379329           92
#
#    playtime_forever_mean  playtime_forever_std  appid_max  \
# 0              75.886792            187.839259     359320
# 1             300.269444            783.701749     346900
# 2            2405.400000           9791.328791        730
# 3             603.611940           2311.529412        730
# 4            4123.141304          16931.177535        730
#
#    playtime_forever_max
# 0                  1130
# 1                  8799
# 2                 53801
# 3                 18306
# 4                118731

# %%
total_per_user = total_per_user.merge(total_per_user_noZero,on='steamid',suffixes=('','_noZero'))

# %%
total_per_user.head()
# Out:
#              steamid  playtime_forever_sum  appid_count  \
# 0  76561197960265754                  8044         1599
# 1  76561197960265942                108097         1142
# 2  76561197960266580                 72162           50
# 3  76561197960267706                 80884          487
# 4  76561197960268165                379329          305
#
#    playtime_forever_mean  playtime_forever_std  appid_max  \
# 0               5.030644             51.720968     359320
# 1              94.655867            461.221806     346900
# 2            1443.240000           7626.036035        730
# 3             166.086242           1238.967945        730
# 4            1243.701639           9455.357241        730
#
#    playtime_forever_max  playtime_forever_sum_noZero  appid_count_noZero  \
# 0                  1130                         8044                 106
# 1                  8799                       108097                 360
# 2                 53801                        72162                  30
# 3                 18306                        80884                 134
# 4                118731                       379329                  92
#
#    playtime_forever_mean_noZero  playtime_forever_std_noZero  \
# 0                     75.886792                   187.839259
# 1                    300.269444                   783.701749
# 2                   2405.400000                  9791.328791
# 3                    603.611940                  2311.529412
# 4                   4123.141304                 16931.177535
#
#    appid_max_noZero  playtime_forever_max_noZero
# 0            359320                         1130
# 1            346900                         8799
# 2               730                        53801
# 3               730                        18306
# 4               730                       118731

# %%
total_per_user[total_per_user['playtime_forever_max'] != total_per_user['playtime_forever_max_noZero']]
# Out:
# Empty DataFrame
# Columns: [steamid, playtime_forever_sum, appid_count, playtime_forever_mean, playtime_forever_std, appid_max, playtime_forever_max, playtime_forever_sum_noZero, appid_count_noZero, playtime_forever_mean_noZero, playtime_forever_std_noZero, appid_max_noZero, playtime_forever_max_noZero]
# Index: []

# %%
total_per_user[total_per_user['appid_max'] != total_per_user['appid_max_noZero']]
# Out:
# Empty DataFrame
# Columns: [steamid, playtime_forever_sum, appid_count, playtime_forever_mean, playtime_forever_std, appid_max, playtime_forever_max, playtime_forever_sum_noZero, appid_count_noZero, playtime_forever_mean_noZero, playtime_forever_std_noZero, appid_max_noZero, playtime_forever_max_noZero]
# Index: []

# %%
total_per_user[total_per_user['playtime_forever_sum'] != total_per_user['playtime_forever_sum_noZero']]
# Out:
# Empty DataFrame
# Columns: [steamid, playtime_forever_sum, appid_count, playtime_forever_mean, playtime_forever_std, appid_max, playtime_forever_max, playtime_forever_sum_noZero, appid_count_noZero, playtime_forever_mean_noZero, playtime_forever_std_noZero, appid_max_noZero, playtime_forever_max_noZero]
# Index: []

# %%
total_per_user = total_per_user.drop(['playtime_forever_max_noZero','appid_max_noZero','playtime_forever_sum_noZero'],axis='columns')

# %%
sns.pairplot(total_per_user)
# Out:
# /anaconda2/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda2/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
total_per_user.to_csv('100k_game_per_user.csv')

# %%
import numpy as np

# %%
sns.pairplot(np.log(total_per_user.dropna()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-937d01808150> in <module>
# ----> 1 sns.pairplot(np.log(total_per_user.dropna()))
#
# /anaconda2/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
#    2109             diag_kws.setdefault("shade", True)
#
# /anaconda2/lib/python3.6/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# /anaconda2/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2657         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2658         color=color, label=label, stacked=stacked, normed=normed,
# -> 2659         **({"data": data} if data is not None else {}), **kwargs)
#    2660
#    2661
#
# /anaconda2/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda2/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6589             # this will automatically overwrite bins,
#    6590             # so that each histogram uses the same bins
# -> 6591             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6592             m = m.astype(float)  # causes problems later if it's an int
#    6593             if mlast is None:
#
# /anaconda2/lib/python3.6/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# /anaconda2/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     415             raise ValueError('`bins` must be positive, when an integer')
#     416
# --> 417         first_edge, last_edge = _get_outer_edges(a, range)
#     418
#     419     elif np.ndim(bins) == 1:
#
# /anaconda2/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     305         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     306             raise ValueError(
# --> 307                 "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#     308     elif a.size == 0:
#     309         # handle empty arrays. Can't determine range, so use 0-1.
#
# ValueError: supplied range of [-inf, 13.128082580797853] is not finite

# %%
total_per_user.groupby('appid_max').count()['steamid'].idxmax()
# Out:
# 730

# %%
total_per_user.nunique()
# Out:
# steamid                         25074
# playtime_forever_sum            24635
# appid_count                      3702
# playtime_forever_mean           25076
# playtime_forever_std            25039
# appid_max                        1140
# playtime_forever_max            23347
# appid_count_noZero               2510
# playtime_forever_mean_noZero    25069
# playtime_forever_std_noZero     24982
# dtype: int64

# %%
df_top5_games_per_user = (df_noZero.loc[df_noZero.groupby(["steamid"])["playtime_forever"].nlargest(5).reset_index(drop=False)['level_1']]).drop('playtime_2weeks',axis='columns')

# %%
total_per_user.head(3)
# Out:
#              steamid  playtime_forever_sum  appid_count  \
# 0  76561197960265754                  8044         1599
# 1  76561197960265942                108097         1142
# 2  76561197960266580                 72162           50
#
#    playtime_forever_mean  playtime_forever_std  appid_max  \
# 0               5.030644             51.720968     359320
# 1              94.655867            461.221806     346900
# 2            1443.240000           7626.036035        730
#
#    playtime_forever_max  appid_count_noZero  playtime_forever_mean_noZero  \
# 0                  1130                 106                     75.886792
# 1                  8799                 360                    300.269444
# 2                 53801                  30                   2405.400000
#
#    playtime_forever_std_noZero
# 0                   187.839259
# 1                   783.701749
# 2                  9791.328791

# %%
df_top5_games_per_user.head(15)
# Out:
#            appid  playtime_forever            steamid
# 7739493   359320              1130  76561197960265754
# 7738398   246900               842  76561197960265754
# 7738410   248820               809  76561197960265754
# 7739049   396650               574  76561197960265754
# 7738487    39210               547  76561197960265754
# 8812845   346900              8799  76561197960265942
# 8812872   363970              6980  76561197960265942
# 8812414   223850              4291  76561197960265942
# 8812107     4920              3575  76561197960265942
# 8813063   350280              2916  76561197960265942
# 16496795     730             53801  76561197960266580
# 16496801  378860              6328  76561197960266580
# 16496813  787860              3072  76561197960266580
# 16496779  227300              2330  76561197960266580
# 16496784  233450              1341  76561197960266580

# %%
df_top5_games_per_user.to_csv('100k_top5game_per_user.csv')

# %%
sns.distplot(np.log(df_top5_games_per_user['playtime_forever']))

# %%
df_top5_games_per_user.describe()
# Out:
#               appid  playtime_forever       steamid
# count  1.244590e+05      1.244590e+05  1.244590e+05
# mean   2.317226e+05      3.722592e+04  7.656120e+16
# std    1.956146e+05      7.538803e+04  1.468602e+08
# min    1.000000e+01      1.000000e+00  7.656120e+16
# 25%    2.233000e+04      6.828000e+03  7.656120e+16
# 50%    2.363900e+05      1.585300e+04  7.656120e+16
# 75%    3.595500e+05      3.781950e+04  7.656120e+16
# max    1.056390e+06      3.097839e+06  7.656120e+16

# %%
df.nunique()
# Out:
# appid               33492
# playtime_2weeks      6200
# playtime_forever    68799
# steamid             27790
# dtype: int64

# %%
df_top5_games_per_user.nunique()
# Out:
# appid                3898
# playtime_forever    58559
# steamid             25093
# dtype: int64

# %%
aps_to_get = list(df_top5_games_per_user.groupby('appid').count().sort_values('steamid',ascending=False).reset_index()['appid'])

# %%
print(aps_to_get)
# Out:
# [730, 271590, 578080, 4000, 218620, 359550, 252950, 72850, 230410, 105600, 550, 252490, 240, 292030, 10, 49520, 8930, 107410, 227300, 377160, 363970, 381210, 444090, 346110, 433850, 304930, 250900, 10190, 238960, 236390, 431960, 582010, 374320, 232090, 1250, 202990, 221100, 346900, 48700, 322330, 42690, 365590, 22380, 287700, 311210, 306130, 413150, 211420, 386360, 33930, 304050, 291550, 211820, 251570, 113200, 39210, 236850, 394360, 500, 620, 489830, 295110, 239140, 255710, 359320, 427520, 281990, 42710, 236430, 304390, 55230, 24960, 203770, 12210, 333930, 222880, 335300, 221380, 582660, 113400, 242760, 231430, 438100, 218230, 294100, 219990, 65800, 8980, 12120, 289070, 384300, 435150, 22490, 812140, 301520, 755790, 227940, 214950, 385770, 550650, 646570, 8500, 244850, 217490, 220200, 504370, 582160, 322170, 268500, 476620, 282660, 72200, 286160, 220, 200510, 453480, 34330, 402840, 109600, 203160, 200710, 80, 270880, 206420, 594570, 460930, 438040, 99900, 388080, 627690, 291480, 204300, 601510, 219640, 334230, 273110, 813820, 275850, 331470, 200210, 444200, 300, 552500, 220240, 45760, 208650, 313340, 323370, 244210, 268850, 391220, 310950, 863550, 50130, 219740, 35450, 261640, 225540, 9900, 365670, 212680, 226320, 242050, 22330, 233450, 329110, 241560, 389730, 386180, 4920, 282800, 588430, 212910, 24240, 611500, 262060, 20900, 221040, 393420, 397900, 440900, 583950, 447040, 320, 17450, 364360, 221680, 10090, 39120, 264710, 91310, 47890, 234140, 524220, 624090, 8190, 610080, 311690, 226700, 555570, 400040, 319630, 236870, 209170, 224260, 3590, 231670, 378120, 307780, 552520, 207890, 629520, 70, 482730, 295270, 389300, 637650, 10500, 326460, 372000, 461910, 47410, 20920, 200260, 24980, 335240, 304030, 447020, 466240, 228200, 310560, 274940, 321360, 479130, 209660, 678950, 438740, 489520, 8870, 685310, 22370, 351030, 325610, 577800, 284160, 560380, 383080, 367520, 814380, 305620, 238460, 215280, 272350, 373420, 9930, 42700, 872790, 291650, 385760, 7940, 209000, 203140, 282900, 212500, 235540, 286940, 236110, 237110, 385800, 371570, 28050, 698780, 228180, 316010, 834910, 21690, 241930, 243470, 214850, 536930, 223470, 273350, 394690, 379720, 841370, 220700, 298110, 356190, 454650, 321040, 638970, 557400, 22320, 333600, 249130, 393380, 379430, 239350, 360430, 224600, 493370, 10180, 208480, 393530, 364470, 268420, 391540, 207140, 552990, 367500, 370240, 485510, 269210, 359870, 431240, 41700, 234330, 475150, 302830, 466170, 287290, 33230, 204360, 700330, 202170, 349040, 383120, 380600, 459820, 263280, 71270, 47810, 630100, 550900, 39140, 418460, 225840, 436150, 44350, 209870, 207610, 612020, 400, 205100, 244450, 339610, 594650, 102500, 282350, 673950, 56400, 564710, 531640, 282070, 12220, 280790, 105450, 588650, 42960, 216150, 493340, 312530, 243870, 323470, 230230, 506540, 314160, 506140, 40800, 513710, 313160, 836620, 40100, 646910, 222900, 728730, 429660, 208090, 596650, 48220, 215080, 380360, 520440, 102700, 389570, 786520, 201810, 251060, 4500, 204880, 17500, 242680, 282440, 17460, 24010, 242920, 245170, 212160, 274170, 735850, 212740, 238260, 57690, 492800, 787860, 12110, 9880, 342200, 253710, 24200, 8800, 592580, 976310, 292730, 292120, 4700, 706220, 290340, 420110, 477160, 570940, 226980, 513650, 248820, 337000, 41070, 431730, 770240, 205790, 234630, 265930, 518790, 34030, 24740, 363890, 645630, 239220, 200110, 299360, 457140, 110800, 312660, 222480, 289650, 893520, 278080, 38600, 299740, 696370, 42680, 224540, 222940, 490220, 355840, 265630, 629760, 287390, 227320, 15620, 248390, 742120, 581320, 48190, 47870, 78000, 227700, 108600, 779340, 750920, 215830, 351970, 307690, 203350, 266840, 290080, 48240, 234670, 30, 9450, 203290, 48720, 257510, 306020, 201790, 421040, 12900, 255220, 35140, 361420, 259680, 204100, 489940, 104700, 212070, 339800, 589360, 447820, 376210, 11020, 238320, 238090, 262410, 666140, 437220, 233860, 254700, 63380, 232910, 626690, 6060, 212480, 632360, 274920, 237310, 394230, 22300, 378860, 627270, 34220,  ...

# %%
len(aps_to_get)
# Out:
# 3898

# %%
with open("Apps_to_get.txt","w+", encoding='utf-8') as file2:
    for app in aps_to_get:
        file2.write("{0}\n".format(app))

# %%
df_top5_games_per_user[['appid','steamid']].to_csv('Pairs_to_get.csv')

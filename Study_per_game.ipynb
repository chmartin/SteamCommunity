# %% [markdown]
# # Study per game information
#
# This notebook looks at the player game information on a per game level.

# %%
import pandas as pd

# %%
df = pd.read_csv("player_game_info.csv").drop("Unnamed: 0", axis='columns')

# %%
df.head()
# Out:
#    appid  playtime_2weeks  playtime_forever            steamid
# 0     10              NaN                32  76561197960434622
# 1     20              NaN                 3  76561197960434622
# 2     30              NaN                 0  76561197960434622
# 3     40              NaN                 0  76561197960434622
# 4     50              NaN                52  76561197960434622

# %%
df.tail()
# Out:
#           appid  playtime_2weeks  playtime_forever            steamid
# 7139917  555570              NaN                 0  76561198059662714
# 7139918  582660              NaN                 0  76561198059662714
# 7139919  601510              NaN                 0  76561198059662714
# 7139920  673950              NaN                 0  76561198059662714
# 7139921  466240              NaN                 0  76561198059662714

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7139922 entries, 0 to 7139921
# Data columns (total 4 columns):
# appid               int64
# playtime_2weeks     float64
# playtime_forever    int64
# steamid             int64
# dtypes: float64(1), int64(3)
# memory usage: 217.9 MB

# %%
df['appid'].nunique()
# Out:
# 33255

# %%
df_noZero = df[df['playtime_forever'] != 0]

# %%
df_noZero['appid'].nunique()
# Out:
# 24906

# %%
df_noZero['steamid'].nunique()
# Out:
# 4095

# %%
df['steamid'].nunique()
# Out:
# 4602

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.groupby('appid').sum()
# Out:
#          playtime_2weeks  playtime_forever       steamid
# appid
# 10              254831.0        27675432.0  2.191947e+20
# 20               14396.0         2153236.0  1.894890e+20
# 30               13927.0         1635036.0  1.642238e+20
# 40               13831.0         1296609.0  1.627691e+20
# 50                2833.0          787745.0  1.933936e+20
# 60               13962.0         1654118.0  1.642238e+20
# 70               63683.0         4643064.0  2.077105e+20
# 80               43396.0         4078952.0  2.012028e+20
# 100              12317.0         1033086.0  2.012028e+20
# 130                718.0          480646.0  1.926280e+20
# 220              27257.0         4629376.0  2.671986e+20
# 240             151022.0        29973623.0  2.422396e+20
# 280               2948.0          763271.0  1.662144e+20
# 300              17220.0         4062803.0  1.708080e+20
# 320              16286.0         3028509.0  2.600784e+20
# 340               2825.0          637621.0  2.747016e+20
# 360              14162.0         1432218.0  2.447662e+20
# 380               6653.0          751626.0  2.440005e+20
# 400               3039.0         2706636.0  2.649783e+20
# 420              20972.0         1166756.0  2.410147e+20
# 500             114921.0         9680012.0  2.063324e+20
# 550             177345.0        27443819.0  3.111447e+20
# 620              27720.0         7445604.0  2.858030e+20
# 730             906521.0       196421821.0  3.175758e+20
# 1002                 0.0            1815.0  1.033576e+19
# 1200              1266.0          299384.0  9.156719e+19
# 1210                 0.0             369.0  3.062448e+17
# 1230                 0.0           29365.0  9.156719e+19
# 1250             49763.0        11258918.0  2.485942e+20
# 1270                 0.0             822.0  1.531224e+17
# ...                  ...               ...           ...
# 1070180              0.0               0.0  1.531224e+17
# 1070240              0.0               0.0  3.062448e+17
# 1070520              0.0               0.0  7.656120e+16
# 1071880              0.0               0.0  3.062448e+17
# 1071890              0.0               0.0  3.062448e+17
# 1072150              0.0             127.0  9.187344e+17
# 1073440              1.0               1.0  3.062448e+17
# 1074340              0.0              37.0  6.890508e+17
# 1074550              0.0               0.0  5.359284e+17
# 1075050              0.0               0.0  7.656120e+16
# 1075060              0.0               0.0  7.656120e+16
# 1075750              0.0               0.0  7.656120e+16
# 1076640              0.0               0.0  7.656120e+16
# 1077580             83.0              83.0  9.187344e+17
# 1078000              0.0               0.0  2.756203e+18
# 1078750              0.0               0.0  5.359284e+17
# 1080250              0.0               0.0  3.828060e+17
# 1081780              0.0               0.0  4.593672e+17
# 1083500              0.0               0.0  1.226510e+20
# 1083650             44.0              44.0  1.071857e+18
# 1084920              0.0               0.0  1.531224e+17
# 1085660              0.0               0.0  1.990591e+18
# 1086850              0.0               0.0  3.062448e+17
# 1087940              0.0               0.0  1.531224e+17
# 1088400            538.0             538.0  2.143714e+18
# 1089860             24.0              24.0  3.598376e+18
# 1090390              0.0              37.0  9.187344e+17
# 1092510              0.0               0.0  2.296836e+17
# 1093280              0.0               0.0  2.296836e+17
# 1096950              0.0               0.0  7.656120e+17
#
# [33255 rows x 3 columns]

# %%
df_noZero.groupby('appid').sum()
# Out:
#          playtime_2weeks  playtime_forever       steamid
# appid
# 10              254831.0        27675432.0  1.305368e+20
# 20               14396.0         2153236.0  5.596624e+19
# 30               13927.0         1635036.0  4.203210e+19
# 40               13831.0         1296609.0  2.871045e+19
# 50                2833.0          787745.0  5.129600e+19
# 60               13962.0         1654118.0  4.295083e+19
# 70               63683.0         4643064.0  1.107075e+20
# 80               43396.0         4078952.0  7.342219e+19
# 100              12317.0         1033086.0  4.471174e+19
# 130                718.0          480646.0  4.746794e+19
# 220              27257.0         4629376.0  2.103902e+20
# 240             151022.0        29973623.0  1.750955e+20
# 280               2948.0          763271.0  5.045383e+19
# 300              17220.0         4062803.0  1.240291e+20
# 320              16286.0         3028509.0  9.340466e+19
# 340               2825.0          637621.0  8.414076e+19
# 360              14162.0         1432218.0  3.261507e+19
# 380               6653.0          751626.0  1.034342e+20
# 400               3039.0         2706636.0  1.753251e+20
# 420              20972.0         1166756.0  1.009077e+20
# 500             114921.0         9680012.0  1.227276e+20
# 550             177345.0        27443819.0  2.671986e+20
# 620              27720.0         7445604.0  2.368803e+20
# 730             906521.0       196421821.0  2.731704e+20
# 1002                 0.0            1815.0  2.220275e+18
# 1200              1266.0          299384.0  3.016511e+19
# 1210                 0.0             369.0  7.656120e+16
# 1230                 0.0           29365.0  9.876395e+18
# 1250             49763.0        11258918.0  1.992122e+20
# 1270                 0.0             822.0  1.531224e+17
# ...                  ...               ...           ...
# 1048540             20.0              20.0  7.656120e+16
# 1048570             33.0             438.0  4.593672e+17
# 1048920              0.0             430.0  7.656120e+16
# 1051200           4162.0            4162.0  1.148418e+18
# 1051310              0.0             173.0  1.531224e+17
# 1055090              0.0             665.0  2.296836e+17
# 1055430             40.0             337.0  2.296836e+17
# 1056390              0.0           19585.0  6.124896e+17
# 1057180              1.0             196.0  1.531224e+17
# 1057680            174.0             174.0  7.656120e+16
# 1058020            636.0            1937.0  1.148418e+18
# 1058320            261.0             261.0  2.296836e+17
# 1059340              3.0             522.0  2.220275e+18
# 1060670             16.0             158.0  1.454663e+18
# 1061090             12.0              43.0  2.296836e+17
# 1061490              1.0              43.0  5.359284e+17
# 1063350              0.0              38.0  7.656120e+16
# 1064130             43.0              43.0  1.531224e+17
# 1065970           1043.0            1043.0  7.656120e+17
# 1066260            758.0             758.0  1.071857e+18
# 1066600              0.0             127.0  5.359284e+17
# 1069460              0.0              22.0  7.656120e+16
# 1072150              0.0             127.0  2.296836e+17
# 1073440              1.0               1.0  7.656120e+16
# 1074340              0.0              37.0  7.656120e+16
# 1077580             83.0              83.0  1.531224e+17
# 1083650             44.0              44.0  4.593672e+17
# 1088400            538.0             538.0  3.062448e+17
# 1089860             24.0              24.0  7.656120e+16
# 1090390              0.0              37.0  7.656120e+16
#
# [24906 rows x 3 columns]

# %%
top_1000_games = list(df_noZero.groupby('appid').sum()[['playtime_forever']].sort_values('playtime_forever',ascending=False)[:1000].index)

# %%
playtime_per_game = pd.DataFrame(df.groupby('appid').sum()[['playtime_forever']])

# %%
count_per_game = df.groupby('appid').count()

# %%
mean_per_game = df.groupby('appid').mean()

# %%
std_per_game = df.groupby('appid').std()

# %%
playtime_per_game = playtime_per_game.reset_index()
count_per_game = count_per_game.reset_index()
mean_per_game = mean_per_game.reset_index()
std_per_game = std_per_game.reset_index()

# %%
print(playtime_per_game.head())
print(count_per_game.head())
print(mean_per_game.head())
print(std_per_game.head())
# Out:
#    appid  playtime_forever
# 0     10        27675432.0
# 1     20         2153236.0
# 2     30         1635036.0
# 3     40         1296609.0
# 4     50          787745.0
#    appid  playtime_2weeks  playtime_forever  steamid
# 0     10               92              2863     2863
# 1     20                8              2475     2475
# 2     30                7              2145     2145
# 3     40                3              2126     2126
# 4     50                7              2526     2526
#    appid  playtime_2weeks  playtime_forever       steamid
# 0     10      2769.902174       9666.584701  7.656120e+16
# 1     20      1799.500000        869.994343  7.656120e+16
# 2     30      1989.571429        762.254545  7.656120e+16
# 3     40      4610.333333        609.881938  7.656120e+16
# 4     50       404.714286        311.854711  7.656120e+16
#    appid  playtime_2weeks  playtime_forever       steamid
# 0     10      5515.167675      68397.978346  1.073686e+08
# 1     20      4842.573194      23905.643377  9.558665e+07
# 2     30      5211.917205      23955.401314  9.927973e+07
# 3     40      7963.684470      22054.311344  9.934185e+07
# 4     50       714.177549       4057.309547  9.664357e+07

# %%
total_per_game = playtime_per_game.merge(count_per_game,on='appid',suffixes=('_sum', '_count'))

# %%
total_per_game = total_per_game.merge(mean_per_game,on='appid',suffixes=('_count','_mean'))

# %%
total_per_game = total_per_game.merge(std_per_game,on='appid',suffixes=('_mean','_std'))

# %%
total_per_game = total_per_game.drop(['steamid','playtime_2weeks','steamid_mean','playtime_2weeks_mean','playtime_2weeks_count'],axis='columns')

# %%
total_per_game[total_per_game['playtime_forever_count'] != total_per_game['steamid_count']]
# Out:
# Empty DataFrame
# Columns: [appid, playtime_forever_sum, playtime_forever_count, steamid_count, playtime_forever_mean, playtime_forever_std]
# Index: []

# %%
total_per_game = total_per_game.drop('steamid_count',axis='columns')

# %%
total_per_game
# Out:
#          appid  playtime_forever_sum  playtime_forever_count  \
# 0           10            27675432.0                    2863
# 1           20             2153236.0                    2475
# 2           30             1635036.0                    2145
# 3           40             1296609.0                    2126
# 4           50              787745.0                    2526
# 5           60             1654118.0                    2145
# 6           70             4643064.0                    2713
# 7           80             4078952.0                    2628
# 8          100             1033086.0                    2628
# 9          130              480646.0                    2516
# 10         220             4629376.0                    3490
# 11         240            29973623.0                    3164
# 12         280              763271.0                    2171
# 13         300             4062803.0                    2231
# 14         320             3028509.0                    3397
# 15         340              637621.0                    3588
# 16         360             1432218.0                    3197
# 17         380              751626.0                    3187
# 18         400             2706636.0                    3461
# 19         420             1166756.0                    3148
# 20         500             9680012.0                    2695
# 21         550            27443819.0                    4064
# 22         620             7445604.0                    3733
# 23         730           196421821.0                    4148
# 24        1002                1815.0                     135
# 25        1200              299384.0                    1196
# 26        1210                 369.0                       4
# 27        1230               29365.0                    1196
# 28        1250            11258918.0                    3247
# 29        1270                 822.0                       2
# ...        ...                   ...                     ...
# 33225  1070180                   0.0                       2
# 33226  1070240                   0.0                       4
# 33227  1070520                   0.0                       1
# 33228  1071880                   0.0                       4
# 33229  1071890                   0.0                       4
# 33230  1072150                 127.0                      12
# 33231  1073440                   1.0                       4
# 33232  1074340                  37.0                       9
# 33233  1074550                   0.0                       7
# 33234  1075050                   0.0                       1
# 33235  1075060                   0.0                       1
# 33236  1075750                   0.0                       1
# 33237  1076640                   0.0                       1
# 33238  1077580                  83.0                      12
# 33239  1078000                   0.0                      36
# 33240  1078750                   0.0                       7
# 33241  1080250                   0.0                       5
# 33242  1081780                   0.0                       6
# 33243  1083500                   0.0                    1602
# 33244  1083650                  44.0                      14
# 33245  1084920                   0.0                       2
# 33246  1085660                   0.0                      26
# 33247  1086850                   0.0                       4
# 33248  1087940                   0.0                       2
# 33249  1088400                 538.0                      28
# 33250  1089860                  24.0                      47
# 33251  1090390                  37.0                      12
# 33252  1092510                   0.0                       3
# 33253  1093280                   0.0                       3
# 33254  1096950                   0.0                      10
#
#        playtime_forever_mean  playtime_forever_std
# 0                9666.584701          68397.978346
# 1                 869.994343          23905.643377
# 2                 762.254545          23955.401314
# 3                 609.881938          22054.311344
# 4                 311.854711           4057.309547
# 5                 771.150583          22350.997052
# 6                1711.413196          28649.586727
# 7                1552.112633          28503.910164
# 8                 393.107306           7028.361225
# 9                 191.035771           2557.515511
# 10               1326.468768          10414.493830
# 11               9473.332174          43535.621307
# 12                351.575772           5014.392236
# 13               1821.068131          25014.951141
# 14                891.524581          20693.773504
# 15                177.709309           3537.382576
# 16                447.988114          20601.252735
# 17                235.841230           1989.362918
# 18                782.038717           9185.737391
# 19                370.634053           3670.117145
# 20               3591.841187          26236.972266
# 21               6752.908219          30179.485004
# 22               1994.536298          18532.569831
# 23              47353.380183          98476.335499
# 24                 13.444444             76.532957
# 25                250.321070           1962.839981
# 26                 92.250000            184.500000
# 27                 24.552676            447.292453
# 28               3467.483215          15437.967181
# 29                411.000000             39.597980
# ...                      ...                   ...
# 33225               0.000000              0.000000
# 33226               0.000000              0.000000
# 33227               0.000000                   NaN
# 33228               0.000000              0.000000
# 33229               0.000000              0.000000
# 33230              10.583333             22.972150
# 33231               0.250000              0.500000
# 33232               4.111111             12.333333
# 33233               0.000000              0.000000
# 33234               0.000000                   NaN
# 33235               0.000000                   NaN
# 33236               0.000000                   NaN
# 33237               0.000000                   NaN
# 33238               6.916667             19.237550
# 33239               0.000000              0.000000
# 33240               0.000000              0.000000
# 33241               0.000000              0.000000
# 33242               0.000000              0.000000
# 33243               0.000000              0.000000
# 33244               3.142857              5.572696
# 33245               0.000000              0.000000
# 33246               0.000000              0.000000
# 33247               0.000000              0.000000
# 33248               0.000000              0.000000
# 33249              19.214286             58.679517
# 33250               0.510638              3.500760
# 33251               3.083333             10.680980
# 33252               0.000000              0.000000
# 33253               0.000000              0.000000
# 33254               0.000000              0.000000
#
# [33255 rows x 5 columns]

# %%
playtime_per_game_noZero = pd.DataFrame(df_noZero.groupby('appid').sum()[['playtime_forever']])

# %%
count_per_game_noZero = df_noZero.groupby('appid').count()

# %%
mean_per_game_noZero = df_noZero.groupby('appid').mean()

# %%
std_per_game_noZero = df_noZero.groupby('appid').std()

# %%
playtime_per_game_noZero = playtime_per_game_noZero.reset_index()
count_per_game_noZero = count_per_game_noZero.reset_index()
mean_per_game_noZero = mean_per_game_noZero.reset_index()
std_per_game_noZero = std_per_game_noZero.reset_index()

# %%
print(playtime_per_game_noZero.head())
print(count_per_game_noZero.head())
print(mean_per_game_noZero.head())
print(std_per_game_noZero.head())
# Out:
#    appid  playtime_forever
# 0     10        27675432.0
# 1     20         2153236.0
# 2     30         1635036.0
# 3     40         1296609.0
# 4     50          787745.0
#    appid  playtime_2weeks  playtime_forever  steamid
# 0     10               92              1705     1705
# 1     20                8               731      731
# 2     30                7               549      549
# 3     40                3               375      375
# 4     50                7               670      670
#    appid  playtime_2weeks  playtime_forever       steamid
# 0     10      2769.902174      16231.924927  7.656120e+16
# 1     20      1799.500000       2945.603283  7.656120e+16
# 2     30      1989.571429       2978.207650  7.656120e+16
# 3     40      4610.333333       3457.624000  7.656120e+16
# 4     50       404.714286       1175.738806  7.656120e+16
#    appid  playtime_2weeks  playtime_forever       steamid
# 0     10      5515.167675      88039.245755  1.109629e+08
# 1     20      4842.573194      43939.119039  9.318429e+07
# 2     30      5211.917205      47313.509464  1.085159e+08
# 3     40      7963.684470      52475.916830  9.388762e+07
# 4     50       714.177549       7817.559625  9.290892e+07

# %%
total_per_game_noZero = playtime_per_game_noZero.merge(count_per_game_noZero,on='appid',suffixes=('_sum', '_count'))

# %%
total_per_game_noZero = total_per_game_noZero.merge(mean_per_game_noZero,on='appid',suffixes=('_count','_mean'))

# %%
total_per_game_noZero = total_per_game_noZero.merge(std_per_game_noZero,on='appid',suffixes=('_mean','_std'))

# %%
total_per_game_noZero = total_per_game_noZero.drop(['steamid','playtime_2weeks','steamid_mean','playtime_2weeks_mean','playtime_2weeks_count'],axis='columns')

# %%
total_per_game_noZero[total_per_game_noZero['playtime_forever_count'] != total_per_game_noZero['steamid_count']]
# Out:
# Empty DataFrame
# Columns: [appid, playtime_forever_sum, playtime_forever_count, steamid_count, playtime_forever_mean, playtime_forever_std]
# Index: []

# %%
total_per_game_noZero = total_per_game_noZero.drop('steamid_count',axis='columns')

# %%
total_per_game_noZero
# Out:
#          appid  playtime_forever_sum  playtime_forever_count  \
# 0           10            27675432.0                    1705
# 1           20             2153236.0                     731
# 2           30             1635036.0                     549
# 3           40             1296609.0                     375
# 4           50              787745.0                     670
# 5           60             1654118.0                     561
# 6           70             4643064.0                    1446
# 7           80             4078952.0                     959
# 8          100             1033086.0                     584
# 9          130              480646.0                     620
# 10         220             4629376.0                    2748
# 11         240            29973623.0                    2287
# 12         280              763271.0                     659
# 13         300             4062803.0                    1620
# 14         320             3028509.0                    1220
# 15         340              637621.0                    1099
# 16         360             1432218.0                     426
# 17         380              751626.0                    1351
# 18         400             2706636.0                    2290
# 19         420             1166756.0                    1318
# 20         500             9680012.0                    1603
# 21         550            27443819.0                    3490
# 22         620             7445604.0                    3094
# 23         730           196421821.0                    3568
# 24        1002                1815.0                      29
# 25        1200              299384.0                     394
# 26        1210                 369.0                       1
# 27        1230               29365.0                     129
# 28        1250            11258918.0                    2602
# 29        1270                 822.0                       2
# ...        ...                   ...                     ...
# 24876  1048540                  20.0                       1
# 24877  1048570                 438.0                       6
# 24878  1048920                 430.0                       1
# 24879  1051200                4162.0                      15
# 24880  1051310                 173.0                       2
# 24881  1055090                 665.0                       3
# 24882  1055430                 337.0                       3
# 24883  1056390               19585.0                       8
# 24884  1057180                 196.0                       2
# 24885  1057680                 174.0                       1
# 24886  1058020                1937.0                      15
# 24887  1058320                 261.0                       3
# 24888  1059340                 522.0                      29
# 24889  1060670                 158.0                      19
# 24890  1061090                  43.0                       3
# 24891  1061490                  43.0                       7
# 24892  1063350                  38.0                       1
# 24893  1064130                  43.0                       2
# 24894  1065970                1043.0                      10
# 24895  1066260                 758.0                      14
# 24896  1066600                 127.0                       7
# 24897  1069460                  22.0                       1
# 24898  1072150                 127.0                       3
# 24899  1073440                   1.0                       1
# 24900  1074340                  37.0                       1
# 24901  1077580                  83.0                       2
# 24902  1083650                  44.0                       6
# 24903  1088400                 538.0                       4
# 24904  1089860                  24.0                       1
# 24905  1090390                  37.0                       1
#
#        playtime_forever_mean  playtime_forever_std
# 0               16231.924927          88039.245755
# 1                2945.603283          43939.119039
# 2                2978.207650          47313.509464
# 3                3457.624000          52475.916830
# 4                1175.738806           7817.559625
# 5                2948.516934          43660.013079
# 6                3210.970954          39187.631834
# 7                4253.338895          47079.066906
# 8                1768.982877          14837.414138
# 9                 775.235484           5110.971126
# 10               1684.634643          11711.318348
# 11              13106.087888          50742.976018
# 12               1158.226100           9054.635600
# 13               2507.903086          29328.779665
# 14               2482.384426          34482.686122
# 15                580.182894           6375.312140
# 16               3362.014085          56407.050011
# 17                556.347890           3026.781737
# 18               1181.937118          11272.561662
# 19                885.247344           5632.972281
# 20               6038.684966          33805.705196
# 21               7863.558453          32433.123464
# 22               2406.465417          20332.757756
# 23              55050.958800         104165.994709
# 24                 62.586207            157.625804
# 25                759.857868           3365.548431
# 26                369.000000                   NaN
# 27                227.635659           1349.539163
# 28               4327.024596          17138.021817
# 29                411.000000             39.597980
# ...                      ...                   ...
# 24876              20.000000                   NaN
# 24877              73.000000            111.225896
# 24878             430.000000                   NaN
# 24879             277.466667            258.566617
# 24880              86.500000             19.091883
# 24881             221.666667            264.076378
# 24882             112.333333             91.358269
# 24883            2448.125000           4839.449657
# 24884              98.000000             90.509668
# 24885             174.000000                   NaN
# 24886             129.133333            182.331279
# 24887              87.000000             71.756533
# 24888              18.000000             53.534368
# 24889               8.315789              4.055896
# 24890              14.333333             11.676187
# 24891               6.142857              6.121780
# 24892              38.000000                   NaN
# 24893              21.500000             17.677670
# 24894             104.300000             84.440709
# 24895              54.142857             83.105917
# 24896              18.142857             22.063760
# 24897              22.000000                   NaN
# 24898              42.333333             29.771351
# 24899               1.000000                   NaN
# 24900              37.000000                   NaN
# 24901              41.500000             34.648232
# 24902               7.333333              6.623192
# 24903             134.500000            101.562788
# 24904              24.000000                   NaN
# 24905              37.000000                   NaN
#
# [24906 rows x 5 columns]

# %%
total_per_game.head()
# Out:
#    appid  playtime_forever_sum  playtime_forever_count  playtime_forever_mean  \
# 0     10            27675432.0                    2863            9666.584701
# 1     20             2153236.0                    2475             869.994343
# 2     30             1635036.0                    2145             762.254545
# 3     40             1296609.0                    2126             609.881938
# 4     50              787745.0                    2526             311.854711
#
#    playtime_forever_std
# 0          68397.978346
# 1          23905.643377
# 2          23955.401314
# 3          22054.311344
# 4           4057.309547

# %%
total_per_game_noZero.head()
# Out:
#    appid  playtime_forever_sum  playtime_forever_count  playtime_forever_mean  \
# 0     10            27675432.0                    1705           16231.924927
# 1     20             2153236.0                     731            2945.603283
# 2     30             1635036.0                     549            2978.207650
# 3     40             1296609.0                     375            3457.624000
# 4     50              787745.0                     670            1175.738806
#
#    playtime_forever_std
# 0          88039.245755
# 1          43939.119039
# 2          47313.509464
# 3          52475.916830
# 4           7817.559625

# %%
total_per_game = total_per_game.merge(total_per_game_noZero,on='appid',suffixes=('','_noZero'))

# %%
total_per_game.head()
# Out:
#    appid  playtime_forever_sum  playtime_forever_count  playtime_forever_mean  \
# 0     10            27675432.0                    2863            9666.584701
# 1     20             2153236.0                    2475             869.994343
# 2     30             1635036.0                    2145             762.254545
# 3     40             1296609.0                    2126             609.881938
# 4     50              787745.0                    2526             311.854711
#
#    playtime_forever_std  playtime_forever_sum_noZero  \
# 0          68397.978346                   27675432.0
# 1          23905.643377                    2153236.0
# 2          23955.401314                    1635036.0
# 3          22054.311344                    1296609.0
# 4           4057.309547                     787745.0
#
#    playtime_forever_count_noZero  playtime_forever_mean_noZero  \
# 0                           1705                  16231.924927
# 1                            731                   2945.603283
# 2                            549                   2978.207650
# 3                            375                   3457.624000
# 4                            670                   1175.738806
#
#    playtime_forever_std_noZero
# 0                 88039.245755
# 1                 43939.119039
# 2                 47313.509464
# 3                 52475.916830
# 4                  7817.559625

# %%
sns.pairplot(total_per_game)
# Out:
# /anaconda2/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda2/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
total_per_game.to_csv('11_June_per_game.csv')

# %%
import numpy as np

# %%
sns.pairplot(np.log(total_per_game[['playtime_forever_sum','playtime_forever_count','playtime_forever_mean','playtime_forever_std']].dropna()))
